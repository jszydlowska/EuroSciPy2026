# %% [markdown]
# # 02 - Exercises

# %%
import pandas as pd
import polars as pl

pd_df = pd.read_csv('palmerpenguins_original.csv')
pl_df = pl.read_csv('palmerpenguins_original.csv')

# %% [markdown]
# ## Exercise 1
# Find the shape of both DataFrames.

# %%
# Your solution here

# %% [markdown]
# ## Exercise 2
# Display the first 10 rows.

# %%
# Your solution here

# %% [markdown]
# ## Exercise 3
# Count missing values.

# %%
# Your solution here

# %% [markdown]
# ## Exercise 4
# Display only species, island and sex.

# %%
# Your solution here

# %% [markdown]
# ## Exercise 5
# Filter female Gentoo penguins heavier than 5000 g.

# %%
# Your solution here

# %% [markdown]
# ## Exercise 6
# Create flipper_length_cm.

# %%
# Your solution here

# %% [markdown]
# ## Exercise 7
# Compute average bill depth by species.

# %%
# Your solution here

# %% [markdown]
# ## Exercise 8
# Which island has the heaviest penguins on average?

# %%
# Your solution here
